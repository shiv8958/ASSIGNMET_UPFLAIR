# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_csv('StudentsPerformance.csv')
print('DATASET')
df
# Out:
# DATASET
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
                         # TYPE OF PLOTS
# 1)  RELATIONAL PLOT:
#It is basically used to show the relation between any two attributes of the dataset
#It contains numerical value on both x and y axis
#It consists of 2 types of plots scatter and line
#By default it represents the data in scatter plot
#It is represented by relplot()

#a)Scatter plot
sns.relplot(x='math score',y ='reading score',data =df)  
#We can also use scatterplot() instead of relplot()

# %%
#Some properties of categorical plot are:
#hue:it differentiates the data based on a different categorical value
#style:it allows customization of  attributes based on a different attribute
#col:it is used to assign different representation based on a attribute
sns.relplot(x='math score',y ='reading score',data =df,hue='race/ethnicity',style='gender',col='lunch')

# %%
#b) Line plot

sns.relplot(x='math score',y ='reading score',data =df,hue='race/ethnicity',style='gender',col='lunch',kind='line')

# %%
# 2) CATEGORICAL PLOT
#It is basically used to compare two categorical variables
#It contains categorical values on both x and y axis
#Common types include : bar plots,violin plots ,box plots,etc.
#It is represnted by catplot()
#We can change the type of representation by using kind

#a)Bar plot
sns.catplot(y='parental level of education',hue='lunch',data=df,x='test preparation course',kind='bar')
#We can also use barplot() instead of catplot()

# %%
#b) Violin plot: 
#The width of violin plot represents the density of data points at different values

sns.catplot(y='parental level of education',hue='lunch',data=df,x='test preparation course',kind='violin')

# %%
sns.catplot(y='parental level of education',x='lunch',hue='gender',data=df,kind='bar')
plt.title('bargraph')   #We can give a title to the plot
plt.show()

# %%
sns.catplot(y='parental level of education',x='lunch',hue='gender',data=df,kind='bar')
plt.title('bargraph')
plt.ylabel('Parent Qualification') #We can label the y axis variables
plt.xlabel('Lunch')         #We can label the x axis variables
plt.show()

# %%
                                      #PIE CHARTS

label =list(df['race/ethnicity'].value_counts().keys())
values=list(df['race/ethnicity'].value_counts().values)
plt.pie(values,labels=label)
plt.show()

# %%
#pie chart has many properties like:
#wedgeprops :using this we can change the properties of the edges of the pie chart
#explode : it is used to seperate specific segments of the pie chart
#autopact :displaying the percentage of each segment as lables
#shadow :adding a show effect to the pie chart
ls = [0,0,0,0,0.4]
plt.pie(values,labels=label,wedgeprops={'ec':'k'},explode= ls,autopct='%1.2f%%',shadow=True)
plt.title('pie chart')
plt.show()

# %%
#c )Boxplot :It represents the distribution of data
     #The line inside the blue box represents median
     #the lines extending from the box are called whiskers ,they extend to minimum and mamimum range within a range
     #The small circles are called outliers they represent extreme values
sns.boxplot(df['math score'])
# Out:
# <Axes: ylabel='math score'>
